# %% [markdown]
# # `sqlite3`: Command Line Program
#
# Reference: https://www.sqlite.org/cli.html

# %% [markdown]
# # 1. Basic Commands
#
# |Terminal Commands| Desciption|
# |-|-|
# |`sqlite3 db.sqlite3`       | create db |
# |`.read sql_queries.sql`    | run script from terminal |

# %% [markdown]
# # 2. Misc Information
# - `.show`
# - `.schema`
# - `.databases`
# - `.tables`
# - `.show`
# - `.show`
# - `.show`

# %% [markdown]
# # basic to-do
# | to-do         | sqlite code|
# |-|-|
# | create db     | `sqlite3 db.sqlite3`|
# | create table  | `.read create_table.sql`|
# | read table    |   `.read read.sql`|
# | update table  | `.read update.sql`|
# | delete table  | `.read delete.sql`|

# %% [markdown]
# # intermedia to-do
#
# SQLite transactions allow executing multiple SQL statements in an atomic manner where either all succeed or everything is rolled back:
#
# - `START TRANSACTION` begins a new transaction block.
# - `COMMIT` writes changes to database.
# - `ROLLBACK` discards all changes since last commit.
#
# Helps maintain consistency and handles errors/crashes.
#
# Transactions ensure bulk database updates either:
#
# - *completely succeed* **or**
# - *fail cleanly*
# - **without side effects**.

# %% [markdown]
# # intermedia to-do table
#
# | to-do                                             | sqlite code                           |learning outcome   |
# |---------------------------------------------------|---------------------------------------|-------------------|
# | create teams_tbl                                  | `.read create_teams_tbl.sql`          |SQLite Transactions|
# | add teams to teams_tbl                            | `.read add_teams_team_tbl.sql`        |SQLite Transactions|
# | ALTER COL 'team_id' to players_tbl as foriegn key | `.read add_team_id_players_tbl.sql`   |SQLite Transactions|
# | transfer messi                                    | `.read txfr_messi.sql`                |SQLite Transactions|
# | transfer players                                  | `.read txfr_multi.sql`                |SQLite Transactions|
